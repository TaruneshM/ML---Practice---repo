# %%
from sklearn.datasets import make_regression as mr
from sklearn.linear_model import LinearRegression 
import numpy as np 
import matplotlib.pyplot as plt

# %%
x,y=mr(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20,random_state=13)
plt.scatter(x,y)

# %%
reg=LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [27.82809103]
# -2.29474455867698

# %%
m=28.48

class GDReg:
    def __init__(self,lr,epoch):
        self.m=27.82
        self.b=-120
        self.lr=lr
        self.epoch=epoch

    def fit(self,x,y):
        # here we calculate b using gradient dececnt 
        for i in range(self.epoch):
            ls=-2*np.sum(y-self.m*x.ravel()- self.b)
            self.b=self.b-(self.lr*ls)
        print(self.b)

# %%
gd=GDReg(0.01,10)

# %%
gd.fit(x,y)
# Out:
# -119.99999999999997
